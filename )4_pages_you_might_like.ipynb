# %%
import json
def load_data(filename):
    with open(filename, "r") as f:
        return json.load(f)

# Function to find pages user might like based on common interests
def user_might_liked(user_id, data):
    # Dictionary to store user interaction with pages
    user_pages = {}
    #polpulate the dictionary
    for user in data['users']:
        user_pages[user['id']] = set(user['liked_pages'])

    # If user is not found return empty in the list
    if user_id not in user_pages:
        return []
        
    user_liked_pages = user_pages[user_id]
    page_suggestion = {}
    
    for other_user, pages in user_pages.items():
        if other_user != user_id:
            shared_pages = user_liked_pages.intersection(pages)
        for page in pages:
            if page not in user_liked_pages:
                page_suggestion[page] = page_suggestion.get('get', 0) + len(shared_pages)

    sorted_pages = sorted(pages_suggestion.items(), key=lambda x: x[1], reverse=True)
    return[page_id for page_id, _ in sorted_pages]

data = load_data("massive_data.json")
user_id = 1
page_recom = user_might_liked(user_id, data)
print(page_recom)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 33
#      29     return[page_id for page_id, _ in sorted_pages]
#      30
#      31 data = load_data("massive_data.json")
#      32 user_id = 1
# ---> 33 page_recom = user_might_liked(user_id, data)
#      34 print(page_recom)
#      35
#
# Cell In[4], line 28, in user_might_liked(user_id, data)
#      24         for page in pages:
#      25             if page not in user_liked_pages:
#      26                 page_suggestion[page] = page_suggestion.get('get', 0) + len(shared_pages)
#      27
# ---> 28     sorted_pages = sorted(pages_suggestion.items(), key=lambda x: x[1], reverse=True)
#      29     return[page_id for page_id, _ in sorted_pages]
#
# NameError: name 'pages_suggestion' is not defined
